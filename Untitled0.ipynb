# %% [markdown]
# ---
#
# # Capstone 20.1 Assignment – Exploratory Data Analysis and Baseline Model
#
# **Dataset:** ADHD Dataset – 4 Classes (u2)
# https://www.kaggle.com/datasets/a7md19/adhd-dataset-4-classes-u2/data
#
# **Objective:**
# Use the full set of behavioral, cognitive (questionnaire), lifestyle, and demographic features to understand ADHD-related patterns and build a baseline multi-class classifier for **Diagnosis_Class** (Target variable).

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, f1_score, classification_report, confusion_matrix

# %%
sns.set(style="whitegrid")
plt.rcParams["figure.figsize"] = (8, 5)
pd.set_option("display.max_columns", 50)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df = pd.read_csv('/content/drive/My Drive/Colab Notebooks/Berkeley_Professional_Certificate_ML_AI/Module_20_Ensemble_Techniques/Required Capstone Assignment 20.1/data/adhd_data.csv')

# %%
df.head()
# Out:
#    Age  Gender Educational_Level Family_History  Sleep_Hours  \
# 0    8       1           Primary             No            8
# 1    9       2           Primary             No           11
# 2    9       1           Primary             No            9
# 3    5       2      Kindergarten            Yes            7
# 4   13       1            Middle             No            3
#
#    Daily_Activity_Hours  Q1_1  Q1_2  Q1_3  Q1_4  Q1_5  Q1_6  Q1_7  Q1_8  Q1_9  \
# 0                     7     0     0     0     1     0     1     1     0     1
# 1                     7     3     2     2     3     2     2     2     3     2
# 2                     5     3     2     3     3     3     2     3     2     2
# 3                    11     3     3     3     2     3     2     2     2     3
# 4                     0     3     2     3     3     2     2     3     3     2
#
#    Q2_1  Q2_2  Q2_3  Q2_4  Q2_5  Q2_6  Q2_7  Q2_8  Q2_9  Diagnosis_Class  \
# ...

# %%
df.shape
# Out:
# (6500, 32)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6500 entries, 0 to 6499
# Data columns (total 32 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Age                           6500 non-null   int64
#  1   Gender                        6500 non-null   int64
#  2   Educational_Level             6500 non-null   object
#  3   Family_History                6500 non-null   object
#  4   Sleep_Hours                   6500 non-null   int64
#  5   Daily_Activity_Hours          6500 non-null   int64
#  6   Q1_1                          6500 non-null   int64
#  7   Q1_2                          6500 non-null   int64
#  8   Q1_3                          6500 non-null   int64
#  9   Q1_4                          6500 non-null   int64
#  10  Q1_5                          6500 non-null   int64
#  11  Q1_6                          6500 non-null   int64
#  12  Q1_7                          6500 non-null   int64
# ...

# %%
df.describe().T
# Out:
#                                count       mean       std  min  25%   50%  \
# Age                           6500.0  11.489846  8.238000  3.0  6.0  10.0
# Gender                        6500.0   1.400000  0.489936  1.0  1.0   1.0
# Sleep_Hours                   6500.0   7.521077  1.874674  3.0  6.0   8.0
# Daily_Activity_Hours          6500.0   4.750615  3.386857  0.0  1.0   5.0
# Q1_1                          6500.0   1.679846  1.108428  0.0  1.0   2.0
# Q1_2                          6500.0   1.683385  1.098783  0.0  1.0   2.0
# Q1_3                          6500.0   1.693846  1.110924  0.0  1.0   2.0
# Q1_4                          6500.0   1.679385  1.102518  0.0  1.0   2.0
# Q1_5                          6500.0   1.683538  1.100856  0.0  1.0   2.0
# Q1_6                          6500.0   1.682923  1.097599  0.0  1.0   2.0
# Q1_7                          6500.0   1.679385  1.100563  0.0  1.0   2.0
# Q1_8                          6500.0   1.692154  1.104691  0.0  1.0   2.0
# ...

# %% [markdown]
# ### No missing values NaNs (all features count is 6500).
# ### Q1_1 to Q1_9 arev items that assess **Hyperactivity**, scale 0-3
# ### Q2_1 to Q2_9 are items that assess **Inattention**, scale 0-3
# ### I will creaet two composite scores by summing the nine hyperactivity items (Q1_1–Q1_9) into a **Hyperactivity_Score** and the nine inattention items (Q2_1–Q2_9) into an **Inattention_Score** (both ranging from 0 to 27). These scores will represent the overall intensity of hyperactive/impulsive and inattentive symptoms for each participant.

# %% [markdown]
# ###0: low hyperactivity, low inattention → likely no ADHD
# ###1: Low hyperactivity, high inattention = inattentive type
# ###2: High hyperactivity, low inattention = hyperactive/impulsive type
# ###3: High hyperactivity, high inattention = combined type

# %%
# Hyperactivity items (Q1_1–Q1_9)
q1_cols = ['Q1_1','Q1_2','Q1_3','Q1_4','Q1_5','Q1_6','Q1_7','Q1_8','Q1_9']

# Inattention items (Q2_1–Q2_9)
q2_cols = ['Q2_1','Q2_2','Q2_3','Q2_4','Q2_5','Q2_6','Q2_7','Q2_8','Q2_9']

df['Hyperactivity_Score'] = df[q1_cols].sum(axis=1)
df['Inattention_Score']   = df[q2_cols].sum(axis=1)

df[['Hyperactivity_Score','Inattention_Score']].describe()
# Out:
#        Hyperactivity_Score  Inattention_Score
# count          6500.000000        6500.000000
# mean             15.165538          15.145385
# std               8.974635           8.995798
# min               0.000000           0.000000
# 25%               5.000000           5.000000
# 50%              21.000000          21.000000
# 75%              23.000000          23.000000
# max              27.000000          27.000000

# %%
plt.figure(figsize=(10,4))

plt.subplot(1,2,1)
plt.hist(df['Hyperactivity_Score'], bins=20)
plt.title('Distribution of Hyperactivity_Score')
plt.xlabel('Score'); plt.ylabel('Count')

plt.subplot(1,2,2)
plt.hist(df['Inattention_Score'], bins=20)
plt.title('Distribution of Inattention_Score')
plt.xlabel('Score'); plt.ylabel('Count')

plt.tight_layout()
plt.show()

# %%
df['Diagnosis_Class'].value_counts(normalize=True, sort=True)
# Out:
# Diagnosis_Class
# 3    0.430769
# 0    0.246154
# 2    0.161538
# 1    0.161538
# Name: proportion, dtype: float64

# %%
y = df['Diagnosis_Class']

print(y.value_counts())

plt.figure(figsize=(6,4))
y.value_counts().sort_index().plot(kind='bar')
plt.xlabel('Diagnosis_Class')
plt.ylabel('Count')
plt.title('Class distribution of Diagnosis_Class')
plt.tight_layout()
plt.show()
# Out:
# Diagnosis_Class
# 3    2800
# 0    1600
# 2    1050
# 1    1050
# Name: count, dtype: int64

# %%
# Clean column names (Age was giving me trouble in later cells)
df.columns = df.columns.astype(str)
df.columns = df.columns.str.strip()
df.columns = df.columns.str.replace('\ufeff', '', regex=True)

print(df.columns.tolist())
# Out:
# ['Age', 'Gender', 'Educational_Level', 'Family_History', 'Sleep_Hours', 'Daily_Activity_Hours', 'Q1_1', 'Q1_2', 'Q1_3', 'Q1_4', 'Q1_5', 'Q1_6', 'Q1_7', 'Q1_8', 'Q1_9', 'Q2_1', 'Q2_2', 'Q2_3', 'Q2_4', 'Q2_5', 'Q2_6', 'Q2_7', 'Q2_8', 'Q2_9', 'Diagnosis_Class', 'Daily_Phone_Usage_Hours', 'Daily_Walking_Running_Hours', 'Difficulty_Organizing_Tasks', 'Focus_Score_Video', 'Daily_Coffee_Tea_Consumption', 'Learning_Difficulties', 'Anxiety_Depression_Levels', 'Hyperactivity_Score', 'Inattention_Score']

# %% [markdown]
# ### The above shows moderate class imbalance. In order to keep the same proportions in Train Test split, I will use **stratify = y**

# %% [markdown]
# ## Meaning of Questionnaire Features
#
# - **Q1_1 – Q1_9:** Hyperactivity / impulsivity items (ordinal 0–3).
# - **Q2_1 – Q2_9:** Inattention items (ordinal 0–3).
#
# In this project we interpret them as follows (simplified DSM-based descriptions):
#
# **Hyperactivity / Impulsivity (Q1_1–Q1_9)**
# - Q1_1: Restlessness or fidgeting.
# - Q1_2: Leaving seat when expected to remain seated.
# - Q1_3: Running/climbing in inappropriate situations / feeling constantly “on the go”.
# - Q1_4: Difficulty playing or engaging quietly.
# - Q1_5: Appearing “driven by a motor”.
# - Q1_6: Talking excessively.
# - Q1_7: Blurting out answers / completing others’ sentences.
# - Q1_8: Difficulty waiting for their turn.
# - Q1_9: Interrupting or intruding on others.
#
# **Inattention (Q2_1–Q2_9)**
# - Q2_1: Careless mistakes / not paying close attention to details.
# - Q2_2: Difficulty sustaining attention.
# - Q2_3: Not seeming to listen when spoken to.
# - Q2_4: Not following through on instructions / not finishing tasks.
# - Q2_5: Difficulty organizing tasks and activities.
# - Q2_6: Avoidance of tasks requiring sustained mental effort.
# - Q2_7: Losing things necessary for tasks.
# - Q2_8: Easily distracted by stimuli or thoughts.
# - Q2_9: Forgetfulness in daily activities.

# %% [markdown]
# ### **Feature engineering** - at composite scores for Hyperactivity and Inattention

# %%
classes = sorted(df["Diagnosis_Class"].unique())

hyperactivity_by_class = [
    df.loc[df["Diagnosis_Class"] == c, "Hyperactivity_Score"] for c in classes
]
inattention_by_class = [
    df.loc[df["Diagnosis_Class"] == c, "Inattention_Score"] for c in classes
]

# %%
df.head()
# Out:
#    Age  Gender Educational_Level Family_History  Sleep_Hours  \
# 0    8       1           Primary             No            8
# 1    9       2           Primary             No           11
# 2    9       1           Primary             No            9
# 3    5       2      Kindergarten            Yes            7
# 4   13       1            Middle             No            3
#
#    Daily_Activity_Hours  Q1_1  Q1_2  Q1_3  Q1_4  Q1_5  Q1_6  Q1_7  Q1_8  Q1_9  \
# 0                     7     0     0     0     1     0     1     1     0     1
# 1                     7     3     2     2     3     2     2     2     3     2
# 2                     5     3     2     3     3     3     2     3     2     2
# 3                    11     3     3     3     2     3     2     2     2     3
# 4                     0     3     2     3     3     2     2     3     3     2
#
#    Q2_1  Q2_2  Q2_3  Q2_4  Q2_5  Q2_6  Q2_7  Q2_8  Q2_9  Diagnosis_Class  \
# ...

# %%
plt.figure(figsize=(12, 5))

# Hyperactivity_Score by class
plt.subplot(1, 2, 1)
plt.boxplot(hyperactivity_by_class, tick_labels=classes, showfliers=False)
plt.xlabel("Diagnosis_Class")
plt.ylabel("Hyperactivity_Score (sum of Q1_1–Q1_9)")
plt.title("Hyperactivity_Score by Diagnosis_Class")

# Inattention_Score by class
plt.subplot(1, 2, 2)
plt.boxplot(inattention_by_class, tick_labels=classes, showfliers=False)
plt.xlabel("Diagnosis_Class")
plt.ylabel("Inattention_Score (sum of Q2_1–Q2_9)")
plt.title("Inattention_Score by Diagnosis_Class")

plt.tight_layout()
plt.show()

# %% [markdown]
# ###0: low hyperactivity, low inattention → likely no ADHD
# ###1: Low hyperactivity, high inattention = inattentive type
# ###2: High hyperactivity, low inattention = hyperactive/impulsive type
# ###3: High hyperactivity, high inattention = combined type

# %% [markdown]
# ###Check for missing values and duplicates

# %%
missing_pct = df.isna().mean().sort_values(ascending=False)
missing_pct
# Out:
# Age                             0.0
# Gender                          0.0
# Educational_Level               0.0
# Family_History                  0.0
# Sleep_Hours                     0.0
# Daily_Activity_Hours            0.0
# Q1_1                            0.0
# Q1_2                            0.0
# Q1_3                            0.0
# Q1_4                            0.0
# Q1_5                            0.0
# Q1_6                            0.0
# Q1_7                            0.0
# Q1_8                            0.0
# Q1_9                            0.0
# Q2_1                            0.0
# Q2_2                            0.0
# Q2_3                            0.0
# Q2_4                            0.0
# Q2_5                            0.0
# Q2_6                            0.0
# Q2_7                            0.0
# Q2_8                            0.0
# Q2_9                            0.0
# Diagnosis_Class                 0.0
# Daily_Phone_Usage_Hours         0.0
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df = df.drop_duplicates().reset_index(drop=True)
print("Shape after dropping duplicates:", df.shape)
# Out:
# Shape after dropping duplicates: (6500, 34)

# %%
X = df[all_feature_cols].copy()
y = df[target_col].copy()

numeric_cols = X.select_dtypes(include=["int64", "float64"]).columns.tolist()
categorical_cols = [c for c in X.columns if c not in numeric_cols]

numeric_cols, categorical_cols
# Out:
# (['Age',
#   'Gender',
#   'Sleep_Hours',
#   'Daily_Activity_Hours',
#   'Daily_Phone_Usage_Hours',
#   'Daily_Walking_Running_Hours',
#   'Daily_Coffee_Tea_Consumption',
#   'Q1_1',
#   'Q1_2',
#   'Q1_3',
#   'Q1_4',
#   'Q1_5',
#   'Q1_6',
#   'Q1_7',
#   'Q1_8',
#   'Q1_9',
#   'Q2_1',
#   'Q2_2',
#   'Q2_3',
#   'Q2_4',
#   'Q2_5',
#   'Q2_6',
#   'Q2_7',
#   'Q2_8',
#   'Q2_9',
#   'Difficulty_Organizing_Tasks',
#   'Focus_Score_Video',
#   'Learning_Difficulties',
#   'Anxiety_Depression_Levels'],
#  ['Educational_Level', 'Family_History'])

# %% [markdown]
# ###Imputation (fill in missing values)

# %%
# Numeric imputation (median)
for col in numeric_cols:
    median_value = X[col].median()
    X[col] = X[col].fillna(median_value)

# Categorical imputation (mode) if any exist
for col in categorical_cols:
    mode_value = X[col].mode(dropna=True)
    if not mode_value.empty:
        X[col] = X[col].fillna(mode_value.iloc[0])

X.isna().sum().sort_values(ascending=False).head()
# Out:
# Age                  0
# Gender               0
# Educational_Level    0
# Family_History       0
# Sleep_Hours          0
# dtype: int64

# %%
# One-hot encode categorical columns
if len(categorical_cols) > 0:
    X_model = pd.get_dummies(X, columns=categorical_cols, drop_first=True)
else:
    X_model = X.copy()

X_model.head()
# Out:
#    Age  Gender  Sleep_Hours  Daily_Activity_Hours  Daily_Phone_Usage_Hours  \
# 0    8       1            8                     7                        2
# 1    9       2           11                     7                        2
# 2    9       1            9                     5                        2
# 3    5       2            7                    11                        6
# 4   13       1            3                     0                        4
#
#    Daily_Walking_Running_Hours  Daily_Coffee_Tea_Consumption  Q1_1  Q1_2  \
# 0                          0.5                             1     0     0
# 1                          0.9                             0     3     2
# 2                          1.4                             0     3     2
# 3                          0.6                             0     3     3
# 4                          1.0                             1     3     2
#
# ...

# %%
cont_features = [
    "Sleep_Hours",
    "Daily_Activity_Hours",
    "Daily_Phone_Usage_Hours",
    "Daily_Walking_Running_Hours",
    "Daily_Coffee_Tea_Consumption",
    "Hyperactivity_Score",
    "Inattention_Score",
    "Focus_Score_Video",
    "Anxiety_Depression_Levels",
]

for col in cont_features:
    plt.figure()
    sns.histplot(df[col], kde=True)
    plt.title(f"Distribution of {col}")
    plt.xlabel(col)
    plt.ylabel("Count")
    plt.tight_layout()
    plt.show()

# %%
#  Creating Core feature groups of the dataset

demographic_cols = [
    "Age",
    "Gender",
    "Educational_Level",
    "Family_History",
]

behavioral_cols = [
    "Sleep_Hours",
    "Daily_Activity_Hours",
    "Daily_Phone_Usage_Hours",
    "Daily_Walking_Running_Hours",
    "Daily_Coffee_Tea_Consumption",
]

other_indicator_cols = [
    "Difficulty_Organizing_Tasks",
    "Focus_Score_Video",
    "Learning_Difficulties",
    "Anxiety_Depression_Levels",
]

#feature list: items + composites
feature_cols = (
    demographic_cols
    + behavioral_cols
    + q1_cols
    + q2_cols
    + other_indicator_cols
    + ["Hyperactivity_Score", "Inattention_Score"]
)

target_col = "Diagnosis_Class"

print("Number of features:", len(feature_cols))
print(feature_cols)
# Out:
# Number of features: 33
# ['Age', 'Gender', 'Educational_Level', 'Family_History', 'Sleep_Hours', 'Daily_Activity_Hours', 'Daily_Phone_Usage_Hours', 'Daily_Walking_Running_Hours', 'Daily_Coffee_Tea_Consumption', 'Q1_1', 'Q1_2', 'Q1_3', 'Q1_4', 'Q1_5', 'Q1_6', 'Q1_7', 'Q1_8', 'Q1_9', 'Q2_1', 'Q2_2', 'Q2_3', 'Q2_4', 'Q2_5', 'Q2_6', 'Q2_7', 'Q2_8', 'Q2_9', 'Difficulty_Organizing_Tasks', 'Focus_Score_Video', 'Learning_Difficulties', 'Anxiety_Depression_Levels', 'Hyperactivity_Score', 'Inattention_Score']

# %%
for col in [
    "Sleep_Hours",
    "Daily_Phone_Usage_Hours",
    "Hyperactivity_Score",
    "Inattention_Score",
]:
    plt.figure()
    sns.boxplot(x=df["Diagnosis_Class"], y=df[col])
    plt.title(f"{col} by Diagnosis_Class")
    plt.xlabel("Diagnosis_Class")
    plt.ylabel(col)
    plt.tight_layout()
    plt.show()

# %%
#build correlation matrix
corr_cols = [
    "Sleep_Hours",
    "Daily_Activity_Hours",
    "Daily_Phone_Usage_Hours",
    "Daily_Walking_Running_Hours",
    "Daily_Coffee_Tea_Consumption",
    "Hyperactivity_Score",
    "Inattention_Score",
    "Focus_Score_Video",
    "Difficulty_Organizing_Tasks",
    "Learning_Difficulties",
    "Anxiety_Depression_Levels",
]

corr_matrix = df[corr_cols].corr()

plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix, annot=True, fmt=".2f", cmap="coolwarm")
plt.title("Correlation Matrix of Key Features")
plt.tight_layout()
plt.show()

# %%
#outliers
for col in [
    "Sleep_Hours",
    "Daily_Phone_Usage_Hours",
    "Hyperactivity_Score",
    "Inattention_Score",
]:
    plt.figure()
    sns.boxplot(x=df[col])
    plt.title(f"Outliers in {col}")
    plt.xlabel(col)
    plt.tight_layout()
    plt.show()

# %%
X = df[feature_cols].copy()
y = df[target_col].copy()

X.head()
# Out:
#    Age  Gender Educational_Level Family_History  Sleep_Hours  \
# 0    8       1           Primary             No            8
# 1    9       2           Primary             No           11
# 2    9       1           Primary             No            9
# 3    5       2      Kindergarten            Yes            7
# 4   13       1            Middle             No            3
#
#    Daily_Activity_Hours  Daily_Phone_Usage_Hours  Daily_Walking_Running_Hours  \
# 0                     7                        2                          0.5
# 1                     7                        2                          0.9
# 2                     5                        2                          1.4
# 3                    11                        6                          0.6
# 4                     0                        4                          1.0
#
#    Daily_Coffee_Tea_Consumption  Q1_1  Q1_2  Q1_3  Q1_4  Q1_5  Q1_6  Q1_7  \
# ...

# %%
y.head()
# Out:
# 0    0
# 1    3
# 2    3
# 3    2
# 4    2
# Name: Diagnosis_Class, dtype: int64

# %%
X_train, X_test, y_train, y_test = train_test_split(X_model, y, test_size=0.2, random_state=42, stratify=y)

scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
#create baseline
log_reg = LogisticRegression(multi_class="multinomial", max_iter=1000, n_jobs=-1)

log_reg.fit(X_train_scaled, y_train)

y_pred = log_reg.predict(X_test_scaled)
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(

# %%
#Evaluate
accuracy = accuracy_score(y_test, y_pred)
macro_f1 = f1_score(y_test, y_pred, average="macro")

print(f"Accuracy: {accuracy:.3f}")
print(f"Macro F1-score: {macro_f1:.3f}")
print("\nClassification Report:\n")
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 1.000
# Macro F1-score: 1.000
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       320
#            1       1.00      1.00      1.00       210
#            2       1.00      1.00      1.00       210
#            3       1.00      1.00      1.00       560
#
#     accuracy                           1.00      1300
#    macro avg       1.00      1.00      1.00      1300
# weighted avg       1.00      1.00      1.00      1300

# %% [markdown]
# ### FI-score of 1 means there is data leakage.
# ### Iwill trainrain only:
#
# Demographics, lifestyle, and other indicators
# (Age, Gender, Educational_Level, Family_History, Sleep_Hours, Daily_Activity_Hours, Daily_Phone_Usage_Hours, Daily_Walking_Running_Hours, Daily_Coffee_Tea_Consumption, Difficulty_Organizing_Tasks, Focus_Score_Video, Learning_Difficulties, Anxiety_Depression_Levels).

# %%
unwanted_cols = q1_cols + q2_cols + ["Hyperactivity_Score", "Inattention_Score"]

# Drop only those that actually exist in X_model
X_model = X_model.drop(
    columns=[c for c in unwanted_cols if c in X_model.columns],
    errors="ignore"
)

print("X_model shape after drop:", X_model.shape)
X_model.head()
# Out:
# X_model shape after drop: (6500, 19)
#    Age  Gender  Sleep_Hours  Daily_Activity_Hours  Daily_Phone_Usage_Hours  \
# 0    8       1            8                     7                        2
# 1    9       2           11                     7                        2
# 2    9       1            9                     5                        2
# 3    5       2            7                    11                        6
# 4   13       1            3                     0                        4
#
#    Daily_Walking_Running_Hours  Daily_Coffee_Tea_Consumption  \
# 0                          0.5                             1
# 1                          0.9                             0
# 2                          1.4                             0
# 3                          0.6                             0
# 4                          1.0                             1
#
#    Difficulty_Organizing_Tasks  Focus_Score_Video  Learning_Difficulties  \
# ...

# %%
X_train, X_test, y_train, y_test = train_test_split( X_model, y, test_size=0.2, random_state=42, stratify=y)

scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

log_reg = LogisticRegression(multi_class="multinomial", max_iter=1000, n_jobs=-1)
log_reg.fit(X_train_scaled, y_train)

y_pred = log_reg.predict(X_test_scaled)

accuracy = accuracy_score(y_test, y_pred)
macro_f1 = f1_score(y_test, y_pred, average="macro")

print(f"Accuracy: {accuracy:.3f}")
print(f"Macro F1-score: {macro_f1:.3f}")
print("\nClassification Report:\n")
print(classification_report(y_test, y_pred))
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# Accuracy: 0.628
# Macro F1-score: 0.442
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       0.63      0.71      0.66       320
#            1       0.49      0.25      0.33       210
#            2       0.00      0.00      0.00       210
#            3       0.65      0.96      0.77       560
#
#     accuracy                           0.63      1300
#    macro avg       0.44      0.48      0.44      1300
# weighted avg       0.51      0.63      0.55      1300
# ...

# %% [markdown]
# ### class 1 recall is 0.25 so many class 1 is missclassified.
# ###Class 2 F1-score precision and recall are 0 , so model is not predicting class 2
#
# ### This could be due to class imbalance. I will try again using class_weight="balanced"

# %%
log_reg = LogisticRegression (multi_class="multinomial", max_iter=1000, n_jobs=-1, class_weight="balanced")
log_reg.fit(X_train_scaled, y_train)

y_pred = log_reg.predict(X_test_scaled)

accuracy = accuracy_score(y_test, y_pred)
macro_f1 = f1_score(y_test, y_pred, average="macro")

print(f"Accuracy: {accuracy:.3f}")
print(f"Macro F1-score: {macro_f1:.3f}")
print("\nClassification Report:\n")
print(classification_report(y_test, y_pred))
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# Accuracy: 0.496
# Macro F1-score: 0.479
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       0.62      0.61      0.61       320
#            1       0.44      0.46      0.45       210
#            2       0.24      0.40      0.30       210
#            3       0.66      0.48      0.56       560
#
#     accuracy                           0.50      1300
#    macro avg       0.49      0.49      0.48      1300
# weighted avg       0.54      0.50      0.51      1300

# %%
cm = confusion_matrix(y_test, y_pred)

plt.figure(figsize=(6, 5))
sns.heatmap(
    cm,
    annot=True,
    fmt="d",
    cmap="Blues",
    xticklabels=sorted(df["Diagnosis_Class"].unique()),
    yticklabels=sorted(df["Diagnosis_Class"].unique())
)
plt.xlabel("Predicted")
plt.ylabel("True")
plt.title("Confusion Matrix – Logistic Regression Baseline")
plt.tight_layout()
plt.show()

# %% [markdown]
# ##**Baseline: 4-class classifier: multinomial logistic regression with balanced class weights using non-questionnaire features only**.
#
# ###This can be used as a baseline model for my capstone project.

# %% [markdown]
# **Features:** Only demographics, lifestyle, and other indicators
#
# Test metrics:
#
# **Accuracy** ≈ 0.50
#
# **Macro F1** ≈ 0.48
#
# Per-class F1 shows non-zero performance for all 4 classes, including 1 and 2.

# %% [markdown]
# ##**Summary**
#
# - **Composite scores:** I first turned the 18 symptom questions into two simple scores:
#
#    - **Hyperactivity_Score** = Q1_1–Q1_9 added together (range 0–27)
#
#    - **Inattention_Score** = Q2_1–Q2_9 added together (range 0–27)
#
# - **Performed EDA**
#
#    - Looked at how the four Diagnosis_Class labels are distributed.
#
#    - Plotted basic distributions for sleep, phone use, movement, mood, and the two new symptom scores.
#
#    - Used boxplots of Hyperactivity_Score and Inattention_Score by Diagnosis_Class. These showed almost perfect separation between classes, which makes it clear that the Q1/Q2 items are essentially encoding the diagnosis rule.
#
#    - Checked correlations between features and scanned for outliers in the main continuous variables.
#
# - This revealed **label leakage**:
#
# - To avoid this, I built a **baseline multinomial logistic regression model** using only non-symptom features:
#
#   - Inputs limited to demographics, lifestyle and other indicators
#   (Age, Gender, Educational_Level, Family_History,
#   Sleep_Hours, Daily_Activity_Hours, Daily_Phone_Usage_Hours,
#   Daily_Walking_Running_Hours, Daily_Coffee_Tea_Consumption,
#   Difficulty_Organizing_Tasks, Focus_Score_Video,
#   Learning_Difficulties, Anxiety_Depression_Levels).
#
#   - Categorical variables were one-hot encoded and all features were standardized.
#
#   - Used class_weight="balanced" so minority classes are not ignored.
#
#   Model results:
#
#     - Test accuracy around **0.50**, macro F1 around **0.48**.
#
#     - **All four classes (0–3) have non-zero F1**, with better recall and F1 for classes 1 and 2 than the unweighted version.
#
# This gives a realistic, clinically sensible baseline that I can now use to compare more complex models and resampling approaches later.
